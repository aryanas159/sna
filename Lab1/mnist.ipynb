# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print("Training data shape:", X_train.shape)
print("Training labels shape:", y_train.shape)
print("Test data shape:", X_test.shape)
print("Test labels shape:", y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# Training data shape: (60000, 28, 28)
# Training labels shape: (60000,)
# Test data shape: (10000, 28, 28)
# Test labels shape: (10000,)

# %%
X_train = X_train/255.0
X_test = X_test/255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
results = model.fit(X_train, y_train, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 60/60 [==============================] - 4s 21ms/step - loss: 0.6003 - accuracy: 0.8422
# Epoch 2/10
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2046 - accuracy: 0.9414
# Epoch 3/10
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1454 - accuracy: 0.9588
# Epoch 4/10
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1106 - accuracy: 0.9681
# Epoch 5/10
# 60/60 [==============================] - 1s 19ms/step - loss: 0.0893 - accuracy: 0.9741
# Epoch 6/10
# 60/60 [==============================] - 1s 18ms/step - loss: 0.0731 - accuracy: 0.9793
# Epoch 7/10
# 60/60 [==============================] - 1s 17ms/step - loss: 0.0603 - accuracy: 0.9830
# Epoch 8/10
# 60/60 [==============================] - 1s 18ms/step - loss: 0.0516 - accuracy: 0.9858
# Epoch 9/10
# 60/60 [==============================] - 1s 18ms/step - loss: 0.0440 - accuracy: 0.9873
# Epoch 10/10
# 60/60 [==============================] - 1s 19ms/step - loss: 0.0370 - accuracy: 0.9901
# <keras.src.callbacks.History object at 0x000002094FB78D10>

# %%
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.0701 - accuracy: 0.9783
# Test Loss: 0.07005136460065842
# Test Accuracy: 0.9782999753952026
