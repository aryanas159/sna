# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print("Training data shape:", X_train.shape)
print("Training labels shape:", y_train.shape)
print("Test data shape:", X_test.shape)
print("Test labels shape:", y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 62s 0us/step
# Training data shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test data shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)

# %%
X_train = X_train/255.0
X_test = X_test/255.0

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(32,32,3)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=35)
# Out:
# Epoch 1/35
# 1563/1563 [==============================] - 24s 13ms/step - loss: 1.8672 - accuracy: 0.3238
# Epoch 2/35
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.6944 - accuracy: 0.3905
# Epoch 3/35
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.6258 - accuracy: 0.4160
# Epoch 4/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.5825 - accuracy: 0.4336
# Epoch 5/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.5489 - accuracy: 0.4461
# Epoch 6/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.5321 - accuracy: 0.4521
# Epoch 7/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.5138 - accuracy: 0.4580
# Epoch 8/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4962 - accuracy: 0.4631
# Epoch 9/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4875 - accuracy: 0.4686
# Epoch 10/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4744 - accuracy: 0.4706
# Epoch 11/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4659 - accuracy: 0.4753
# Epoch 12/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4529 - accuracy: 0.4782
# Epoch 13/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4457 - accuracy: 0.4826
# Epoch 14/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4393 - accuracy: 0.4843
# Epoch 15/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4294 - accuracy: 0.4889
# Epoch 16/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4249 - accuracy: 0.4881
# Epoch 17/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4248 - accuracy: 0.4891
# Epoch 18/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4108 - accuracy: 0.4945
# Epoch 19/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4100 - accuracy: 0.4925
# Epoch 20/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4046 - accuracy: 0.4975
# Epoch 21/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3994 - accuracy: 0.4955
# Epoch 22/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3932 - accuracy: 0.5003
# Epoch 23/35
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.3857 - accuracy: 0.5042
# Epoch 24/35
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.3832 - accuracy: 0.5036
# Epoch 25/35
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.3774 - accuracy: 0.5054
# Epoch 26/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3767 - accuracy: 0.5075
# Epoch 27/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3744 - accuracy: 0.5070
# Epoch 28/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3718 - accuracy: 0.5096
# Epoch 29/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3655 - accuracy: 0.5086
# Epoch 30/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3630 - accuracy: 0.5122
# Epoch 31/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3585 - accuracy: 0.5132
# Epoch 32/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3532 - accuracy: 0.5133
# Epoch 33/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3507 - accuracy: 0.5159
# Epoch 34/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3505 - accuracy: 0.5137
# Epoch 35/35
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3465 - accuracy: 0.5171

# %%
test_loss,test_acc=model.evaluate(X_test,y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 1.4995 - accuracy: 0.4760
# Test Loss: 1.4994884729385376
# Test Accuracy: 0.47600001096725464
